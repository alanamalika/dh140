# %% [markdown]
# # Assignment 02

# %% [markdown]
# Name: Alana Malika
#
# Link to dataset: https://corgis-edu.github.io/corgis/csv/billionaires/
#
# Description: Researchers have compiled a multi-decade database of the super-rich. Building off the Forbes World’s Billionaires lists from 1996-2014, scholars at Peterson Institute for International Economics have added a couple dozen more variables about each billionaire - including whether they were self-made or inherited their wealth. (Roughly half of European billionaires and one-third of U.S. billionaires got a significant financial boost from family, the authors estimate.) (Taken from CORGIS dataset project)

# %%
# commands to read the datafile
import billionaires
billionaire = billionaires.get_billionaire()

# %%
billionaire
# Out:
# [{'name': 'Bill Gates',
#   'rank': 1,
#   'year': 1996,
#   'company': {'founded': 1975,
#    'name': 'Microsoft',
#    'relationship': 'founder',
#    'sector': ' Software',
#    'type': 'new'},
#   'demographics': {'age': 40, 'gender': 'male'},
#   'location': {'citizenship': 'United States',
#    'country code': 'USA',
#    'gdp': 8100000000000.0,
#    'region': 'North America'},
#   'wealth': {'type': 'founder non-finance',
#    'worth in billions': 18.5,
#    'how': {'category': 'New Sectors',
#     'from emerging': True,
#     'industry': 'Technology-Computer',
#     'inherited': 'not inherited',
#     'was founder': True,
#     'was political': True}}},
#  {'name': 'Bill Gates',
#   'rank': 1,
#   'year': 2001,
#   'company': {'founded': 1975,
#    'name': 'Microsoft',
#    'relationship': 'founder',
#    'sector': ' Software',
#    'type': 'new'},
#   'demographics': {'age': 45, 'gender': 'male'},
#   'location': {'citizenship': 'United States',
#    'country code': 'USA',
# ...

# %%
# mathematical operation
a = billionaire[0]['wealth']['worth in billions']
b = billionaire[2]['wealth']['worth in billions']
c = b - a
# conditional expression
if c > 0:
    print('Bill Gates remained a billionaire between 1996 and 2014 and his networth rose by ' + str(c) + ' billion dollars.')
elif c <= 0:
    print ('Bill Gates remained a billionaire between 1996 and 2014 but his networth dropped by ' + str(c) + ' billion dollars.')
# Out:
# Bill Gates remained a billionaire between 1996 and 2014 and his networth rose by 57.5 billion dollars.

# %%
d = billionaire[0]['wealth']['how']['inherited']
print('His wealth was ' + str(d) + '.')
# Out:
# His wealth was not inherited.

# %% [markdown]
# Here is a list of billionaires from 1996 to 2014 and whether their wealth was inherited or not:

# %%
# for loop
for i in billionaire:
    print (str(i['name']+':'+i['wealth']['how']['inherited']))
# Out:
# Bill Gates:not inherited
# Bill Gates:not inherited
# Bill Gates:not inherited
# Warren Buffett:not inherited
# Warren Buffett:not inherited
# Carlos Slim Helu:not inherited
# Oeri Hoffman and Sacher:3rd generation
# Paul Allen:not inherited
# Amancio Ortega:not inherited
# Lee Shau Kee:not inherited
# Larry Ellison:not inherited
# Warren Buffett:not inherited
# Tsai Wan-lin:not inherited
# Theo and Karl Albrecht:not inherited
# Larry Ellison:not inherited
# Walter Thomas and Raymond Kwok:father
# Prince Alwaleed Bin Talal Alsaud:not inherited
# Charles Koch:father
# David Koch:father
# Li Ka-shing:not inherited
# Jim Walton:father
# Yoshiaki Tsutsumi:father
# John Walton:father
# Sheldon Adelson:not inherited
# Theo and Karl Albrecht:father
# S Robson Walton:father
# Christy Walton:spouse/widow
# Hans and Gad Rausing:father
# Alice Walton:father
# Helen Walton:spouse/widow
# Jim Walton:father
# Johanna Quandt:spouse/widow
# Liliane Bettencourt:father
# Haniel family:not inherited
# ...

# %% [markdown]
# This function calculates how many hours and years it will take for someone to become a billionaire, without taxes or expense, if they earn w dollars per hour.

# %%
# function (both a new function definition and an execution of that function)
def f(w):
    hours = 1000000000/w
    years = hours/8760
    saying = 'You will have to work ' + str(hours) + ' hours or ' + str(years) + ' years to become a billionaire if you earn ' + str(w) + ' dollars per hour before tax and expenses.'
    return (saying)

# %% [markdown]
# The minimum wage in California is 14 dollars so I will use this amount as an example of this function's execution.

# %%
w = 14
f (14)
# Out:
# 'You will have to work 71428571.42857143 hours or 8153.946510110894 years to become a billionaire if you earn 14 dollars per hour before tax and expenses.'
